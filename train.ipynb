# %%
# !pip install transformers datasets peft accelerate evaluate rouge-score bert-score
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.8.1)
# Collecting evaluate
#   Using cached evaluate-0.4.4-py3-none-any.whl.metadata (9.5 kB)
# Collecting rouge-score
#   Using cached rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert-score
#   Using cached bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13.0->peft)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13.0->peft)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13.0->peft)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13.0->peft)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13.0->peft)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13.0->peft)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score) (3.2.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Using cached evaluate-0.4.4-py3-none-any.whl (84 kB)
# Using cached bert_score-0.3.13-py3-none-any.whl (61 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 48.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.5 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=8daf7ec856496bc4b5763598d62fe435d8795209a72702750d6164949834b6bb
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, rouge-score, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, evaluate, bert-score
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bert-score-0.3.13 evaluate-0.4.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rouge-score-0.1.2

# %%
from datasets import load_dataset
import pandas as pd
from datasets import Dataset

df = pd.read_csv("/content/sample_data/merged_bbc_fmp2.csv")

dataset = Dataset.from_pandas(df)
data = dataset.train_test_split(test_size=0.1)

# %%
len(df)
# Out:
# 4127

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("t5-small")

max_source = 512
max_target = 128

def preprocess(examples):
    inputs = ["summarize: " + t for t in examples["text"]]
    model_inputs = tokenizer(inputs, truncation=True, padding="max_length", max_length=max_source)
    labels = tokenizer(examples["summary"], truncation=True, padding="max_length", max_length=max_target).input_ids
    model_inputs["labels"] = [
        [(lbl if lbl != tokenizer.pad_token_id else -100) for lbl in label]
        for label in labels
    ]
    return model_inputs

tokenized = data.map(preprocess, batched=True, remove_columns=data["train"].column_names)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Map:   0%|          | 0/3714 [00:00<?, ? examples/s]
# Map:   0%|          | 0/413 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForSeq2SeqLM
from peft import LoraConfig, get_peft_model, TaskType

model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")
peft_config = LoraConfig(
    task_type=TaskType.SEQ_2_SEQ_LM,
    r=8,
    lora_alpha=16,
    target_modules=["q", "v"],
    lora_dropout=0.05
)
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# trainable params: 294,912 || all params: 60,801,536 || trainable%: 0.4850

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq

training_args = Seq2SeqTrainingArguments(
    output_dir="t5-lora-output",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=3e-4,
    num_train_epochs=3,
    logging_steps=100,
    eval_steps=500,
    save_steps=1000,
    save_total_limit=2,
    fp16=True,
    predict_with_generate=True,
    report_to="none"
)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized["train"],
    eval_dataset=tokenized["test"],
    data_collator=data_collator,
    tokenizer=tokenizer,

)
# Out:
# /tmp/ipython-input-7-480894582.py:20: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# No label_names provided for model class `PeftModelForSeq2SeqLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.

# %%
trainer.train()
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='1395' max='1395' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1395/1395 04:05, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.293200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.152600</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.065000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.031200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.994000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.969700</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.003200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.929400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.966500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.912500</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.895500</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.944000</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.015900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1395, training_loss=1.011670135169901, metrics={'train_runtime': 247.8954, 'train_samples_per_second': 44.946, 'train_steps_per_second': 5.627, 'total_flos': 1518072665997312.0, 'train_loss': 1.011670135169901, 'epoch': 3.0})

# %%
model.save_pretrained("t5-2000-summarizer")
tokenizer.save_pretrained("t5-2000-summarizer")
# Out:
# ('t5-2000-summarizer/tokenizer_config.json',
#  't5-2000-summarizer/special_tokens_map.json',
#  't5-2000-summarizer/spiece.model',
#  't5-2000-summarizer/added_tokens.json',
#  't5-2000-summarizer/tokenizer.json')

# %%
import evaluate
rouge = evaluate.load("rouge")
preds = trainer.predict(tokenized["test"]).predictions
decoded = tokenizer.batch_decode(preds, skip_special_tokens=True)
refs = data["test"]["summary"]
print(rouge.compute(predictions=decoded, references=refs))
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# {'rouge1': np.float64(0.2266784078966924), 'rouge2': np.float64(0.12936339659467372), 'rougeL': np.float64(0.20333923288003675), 'rougeLsum': np.float64(0.2032873179212622)}

# %%
from bert_score import score
P, R, F1 = score(decoded, refs, lang="en")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for i in range(len(decoded)):
    print(f"Summary {i+1}:")
    print(f"  Precision: {P[i]:.3f} (How much info is correct)")
    print(f"  Recall:    {R[i]:.3f} (How much reference is covered)")
    print(f"  F1:        {F1[i]:.3f} (Balance)\n")
# Out:
# Summary 1:
#   Precision: 0.925 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.871 (Balance)
#
# Summary 2:
#   Precision: 0.812 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.815 (Balance)
#
# Summary 3:
#   Precision: 0.753 (How much info is correct)
#   Recall:    0.811 (How much reference is covered)
#   F1:        0.781 (Balance)
#
# Summary 4:
#   Precision: 0.811 (How much info is correct)
#   Recall:    0.789 (How much reference is covered)
#   F1:        0.800 (Balance)
#
# Summary 5:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.804 (How much reference is covered)
#   F1:        0.827 (Balance)
#
# Summary 6:
#   Precision: 0.925 (How much info is correct)
#   Recall:    0.878 (How much reference is covered)
#   F1:        0.901 (Balance)
#
# Summary 7:
#   Precision: 0.963 (How much info is correct)
#   Recall:    0.878 (How much reference is covered)
#   F1:        0.918 (Balance)
#
# Summary 8:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.825 (How much reference is covered)
#   F1:        0.844 (Balance)
#
# Summary 9:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.839 (Balance)
#
# Summary 10:
#   Precision: 0.869 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 11:
#   Precision: 0.857 (How much info is correct)
#   Recall:    0.841 (How much reference is covered)
#   F1:        0.849 (Balance)
#
# Summary 12:
#   Precision: 0.961 (How much info is correct)
#   Recall:    0.915 (How much reference is covered)
#   F1:        0.937 (Balance)
#
# Summary 13:
#   Precision: 0.853 (How much info is correct)
#   Recall:    0.748 (How much reference is covered)
#   F1:        0.797 (Balance)
#
# Summary 14:
#   Precision: 0.962 (How much info is correct)
#   Recall:    0.858 (How much reference is covered)
#   F1:        0.907 (Balance)
#
# Summary 15:
#   Precision: 0.922 (How much info is correct)
#   Recall:    0.868 (How much reference is covered)
#   F1:        0.894 (Balance)
#
# Summary 16:
#   Precision: 0.824 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.822 (Balance)
#
# Summary 17:
#   Precision: 0.769 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.788 (Balance)
#
# Summary 18:
#   Precision: 0.821 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.823 (Balance)
#
# Summary 19:
#   Precision: 0.817 (How much info is correct)
#   Recall:    0.833 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 20:
#   Precision: 0.959 (How much info is correct)
#   Recall:    0.865 (How much reference is covered)
#   F1:        0.910 (Balance)
#
# Summary 21:
#   Precision: 0.933 (How much info is correct)
#   Recall:    0.892 (How much reference is covered)
#   F1:        0.912 (Balance)
#
# Summary 22:
#   Precision: 0.818 (How much info is correct)
#   Recall:    0.738 (How much reference is covered)
#   F1:        0.776 (Balance)
#
# Summary 23:
#   Precision: 0.878 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.850 (Balance)
#
# Summary 24:
#   Precision: 0.926 (How much info is correct)
#   Recall:    0.840 (How much reference is covered)
#   F1:        0.881 (Balance)
#
# Summary 25:
#   Precision: 0.860 (How much info is correct)
#   Recall:    0.843 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 26:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 27:
#   Precision: 0.954 (How much info is correct)
#   Recall:    0.753 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 28:
#   Precision: 0.904 (How much info is correct)
#   Recall:    0.859 (How much reference is covered)
#   F1:        0.881 (Balance)
#
# Summary 29:
#   Precision: 0.955 (How much info is correct)
#   Recall:    0.864 (How much reference is covered)
#   F1:        0.907 (Balance)
#
# Summary 30:
#   Precision: 0.874 (How much info is correct)
#   Recall:    0.837 (How much reference is covered)
#   F1:        0.855 (Balance)
#
# Summary 31:
#   Precision: 0.775 (How much info is correct)
#   Recall:    0.786 (How much reference is covered)
#   F1:        0.780 (Balance)
#
# Summary 32:
#   Precision: 0.869 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.844 (Balance)
#
# Summary 33:
#   Precision: 0.841 (How much info is correct)
#   Recall:    0.797 (How much reference is covered)
#   F1:        0.818 (Balance)
#
# Summary 34:
#   Precision: 0.832 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 35:
#   Precision: 0.859 (How much info is correct)
#   Recall:    0.824 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 36:
#   Precision: 0.826 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.829 (Balance)
#
# Summary 37:
#   Precision: 0.835 (How much info is correct)
#   Recall:    0.806 (How much reference is covered)
#   F1:        0.820 (Balance)
#
# Summary 38:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.830 (How much reference is covered)
#   F1:        0.844 (Balance)
#
# Summary 39:
#   Precision: 0.898 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.859 (Balance)
#
# Summary 40:
#   Precision: 0.888 (How much info is correct)
#   Recall:    0.861 (How much reference is covered)
#   F1:        0.874 (Balance)
#
# Summary 41:
#   Precision: 0.802 (How much info is correct)
#   Recall:    0.784 (How much reference is covered)
#   F1:        0.793 (Balance)
#
# Summary 42:
#   Precision: 0.809 (How much info is correct)
#   Recall:    0.822 (How much reference is covered)
#   F1:        0.815 (Balance)
#
# Summary 43:
#   Precision: 0.876 (How much info is correct)
#   Recall:    0.874 (How much reference is covered)
#   F1:        0.875 (Balance)
#
# Summary 44:
#   Precision: 0.838 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.832 (Balance)
#
# Summary 45:
#   Precision: 0.816 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.810 (Balance)
#
# Summary 46:
#   Precision: 0.917 (How much info is correct)
#   Recall:    0.862 (How much reference is covered)
#   F1:        0.889 (Balance)
#
# Summary 47:
#   Precision: 0.848 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.831 (Balance)
#
# Summary 48:
#   Precision: 0.949 (How much info is correct)
#   Recall:    0.924 (How much reference is covered)
#   F1:        0.936 (Balance)
#
# Summary 49:
#   Precision: 0.967 (How much info is correct)
#   Recall:    0.858 (How much reference is covered)
#   F1:        0.909 (Balance)
#
# Summary 50:
#   Precision: 0.890 (How much info is correct)
#   Recall:    0.708 (How much reference is covered)
#   F1:        0.788 (Balance)
#
# Summary 51:
#   Precision: 0.891 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.868 (Balance)
#
# Summary 52:
#   Precision: 0.816 (How much info is correct)
#   Recall:    0.682 (How much reference is covered)
#   F1:        0.743 (Balance)
#
# Summary 53:
#   Precision: 0.891 (How much info is correct)
#   Recall:    0.868 (How much reference is covered)
#   F1:        0.880 (Balance)
#
# Summary 54:
#   Precision: 0.930 (How much info is correct)
#   Recall:    0.842 (How much reference is covered)
#   F1:        0.884 (Balance)
#
# Summary 55:
#   Precision: 0.831 (How much info is correct)
#   Recall:    0.757 (How much reference is covered)
#   F1:        0.792 (Balance)
#
# Summary 56:
#   Precision: 0.831 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 57:
#   Precision: 0.963 (How much info is correct)
#   Recall:    0.875 (How much reference is covered)
#   F1:        0.917 (Balance)
#
# Summary 58:
#   Precision: 0.839 (How much info is correct)
#   Recall:    0.847 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 59:
#   Precision: 0.842 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 60:
#   Precision: 0.959 (How much info is correct)
#   Recall:    0.860 (How much reference is covered)
#   F1:        0.907 (Balance)
#
# Summary 61:
#   Precision: 0.927 (How much info is correct)
#   Recall:    0.833 (How much reference is covered)
#   F1:        0.877 (Balance)
#
# Summary 62:
#   Precision: 0.799 (How much info is correct)
#   Recall:    0.827 (How much reference is covered)
#   F1:        0.813 (Balance)
#
# Summary 63:
#   Precision: 0.908 (How much info is correct)
#   Recall:    0.836 (How much reference is covered)
#   F1:        0.871 (Balance)
#
# Summary 64:
#   Precision: 0.977 (How much info is correct)
#   Recall:    0.845 (How much reference is covered)
#   F1:        0.907 (Balance)
#
# Summary 65:
#   Precision: 0.884 (How much info is correct)
#   Recall:    0.785 (How much reference is covered)
#   F1:        0.831 (Balance)
#
# Summary 66:
#   Precision: 0.769 (How much info is correct)
#   Recall:    0.807 (How much reference is covered)
#   F1:        0.787 (Balance)
#
# Summary 67:
#   Precision: 0.972 (How much info is correct)
#   Recall:    0.858 (How much reference is covered)
#   F1:        0.911 (Balance)
#
# Summary 68:
#   Precision: 0.857 (How much info is correct)
#   Recall:    0.857 (How much reference is covered)
#   F1:        0.857 (Balance)
#
# Summary 69:
#   Precision: 0.844 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.824 (Balance)
#
# Summary 70:
#   Precision: 0.927 (How much info is correct)
#   Recall:    0.843 (How much reference is covered)
#   F1:        0.883 (Balance)
#
# Summary 71:
#   Precision: 0.861 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.837 (Balance)
#
# Summary 72:
#   Precision: 0.834 (How much info is correct)
#   Recall:    0.811 (How much reference is covered)
#   F1:        0.823 (Balance)
#
# Summary 73:
#   Precision: 0.881 (How much info is correct)
#   Recall:    0.844 (How much reference is covered)
#   F1:        0.862 (Balance)
#
# Summary 74:
#   Precision: 0.868 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 75:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.806 (How much reference is covered)
#   F1:        0.830 (Balance)
#
# Summary 76:
#   Precision: 0.945 (How much info is correct)
#   Recall:    0.876 (How much reference is covered)
#   F1:        0.910 (Balance)
#
# Summary 77:
#   Precision: 0.850 (How much info is correct)
#   Recall:    0.835 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 78:
#   Precision: 0.850 (How much info is correct)
#   Recall:    0.798 (How much reference is covered)
#   F1:        0.823 (Balance)
#
# Summary 79:
#   Precision: 0.871 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 80:
#   Precision: 0.944 (How much info is correct)
#   Recall:    0.852 (How much reference is covered)
#   F1:        0.896 (Balance)
#
# Summary 81:
#   Precision: 0.977 (How much info is correct)
#   Recall:    0.869 (How much reference is covered)
#   F1:        0.920 (Balance)
#
# Summary 82:
#   Precision: 0.969 (How much info is correct)
#   Recall:    0.912 (How much reference is covered)
#   F1:        0.940 (Balance)
#
# Summary 83:
#   Precision: 0.828 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.822 (Balance)
#
# Summary 84:
#   Precision: 0.866 (How much info is correct)
#   Recall:    0.841 (How much reference is covered)
#   F1:        0.854 (Balance)
#
# Summary 85:
#   Precision: 0.877 (How much info is correct)
#   Recall:    0.839 (How much reference is covered)
#   F1:        0.858 (Balance)
#
# Summary 86:
#   Precision: 0.893 (How much info is correct)
#   Recall:    0.827 (How much reference is covered)
#   F1:        0.859 (Balance)
#
# Summary 87:
#   Precision: 0.846 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.833 (Balance)
#
# Summary 88:
#   Precision: 0.930 (How much info is correct)
#   Recall:    0.836 (How much reference is covered)
#   F1:        0.880 (Balance)
#
# Summary 89:
#   Precision: 0.834 (How much info is correct)
#   Recall:    0.835 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 90:
#   Precision: 0.901 (How much info is correct)
#   Recall:    0.887 (How much reference is covered)
#   F1:        0.894 (Balance)
#
# Summary 91:
#   Precision: 0.871 (How much info is correct)
#   Recall:    0.824 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 92:
#   Precision: 0.807 (How much info is correct)
#   Recall:    0.795 (How much reference is covered)
#   F1:        0.801 (Balance)
#
# Summary 93:
#   Precision: 0.843 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.824 (Balance)
#
# Summary 94:
#   Precision: 0.824 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 95:
#   Precision: 0.870 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.850 (Balance)
#
# Summary 96:
#   Precision: 0.930 (How much info is correct)
#   Recall:    0.839 (How much reference is covered)
#   F1:        0.882 (Balance)
#
# Summary 97:
#   Precision: 0.827 (How much info is correct)
#   Recall:    0.793 (How much reference is covered)
#   F1:        0.810 (Balance)
#
# Summary 98:
#   Precision: 0.834 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.829 (Balance)
#
# Summary 99:
#   Precision: 0.947 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.896 (Balance)
#
# Summary 100:
#   Precision: 0.882 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.846 (Balance)
#
# Summary 101:
#   Precision: 0.853 (How much info is correct)
#   Recall:    0.837 (How much reference is covered)
#   F1:        0.845 (Balance)
#
# Summary 102:
#   Precision: 0.876 (How much info is correct)
#   Recall:    0.851 (How much reference is covered)
#   F1:        0.863 (Balance)
#
# Summary 103:
#   Precision: 0.872 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.846 (Balance)
#
# Summary 104:
#   Precision: 0.871 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.858 (Balance)
#
# Summary 105:
#   Precision: 0.951 (How much info is correct)
#   Recall:    0.869 (How much reference is covered)
#   F1:        0.908 (Balance)
#
# Summary 106:
#   Precision: 0.889 (How much info is correct)
#   Recall:    0.873 (How much reference is covered)
#   F1:        0.881 (Balance)
#
# Summary 107:
#   Precision: 0.902 (How much info is correct)
#   Recall:    0.893 (How much reference is covered)
#   F1:        0.897 (Balance)
#
# Summary 108:
#   Precision: 0.797 (How much info is correct)
#   Recall:    0.772 (How much reference is covered)
#   F1:        0.784 (Balance)
#
# Summary 109:
#   Precision: 0.846 (How much info is correct)
#   Recall:    0.861 (How much reference is covered)
#   F1:        0.853 (Balance)
#
# Summary 110:
#   Precision: 0.874 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.862 (Balance)
#
# Summary 111:
#   Precision: 0.866 (How much info is correct)
#   Recall:    0.888 (How much reference is covered)
#   F1:        0.877 (Balance)
#
# Summary 112:
#   Precision: 0.920 (How much info is correct)
#   Recall:    0.891 (How much reference is covered)
#   F1:        0.905 (Balance)
#
# Summary 113:
#   Precision: 0.860 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.839 (Balance)
#
# Summary 114:
#   Precision: 0.843 (How much info is correct)
#   Recall:    0.807 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 115:
#   Precision: 0.834 (How much info is correct)
#   Recall:    0.771 (How much reference is covered)
#   F1:        0.801 (Balance)
#
# Summary 116:
#   Precision: 0.960 (How much info is correct)
#   Recall:    0.893 (How much reference is covered)
#   F1:        0.925 (Balance)
#
# Summary 117:
#   Precision: 0.865 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 118:
#   Precision: 0.891 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.857 (Balance)
#
# Summary 119:
#   Precision: 0.828 (How much info is correct)
#   Recall:    0.810 (How much reference is covered)
#   F1:        0.819 (Balance)
#
# Summary 120:
#   Precision: 0.814 (How much info is correct)
#   Recall:    0.784 (How much reference is covered)
#   F1:        0.799 (Balance)
#
# Summary 121:
#   Precision: 0.966 (How much info is correct)
#   Recall:    0.892 (How much reference is covered)
#   F1:        0.928 (Balance)
#
# Summary 122:
#   Precision: 0.797 (How much info is correct)
#   Recall:    0.762 (How much reference is covered)
#   F1:        0.779 (Balance)
#
# Summary 123:
#   Precision: 0.897 (How much info is correct)
#   Recall:    0.870 (How much reference is covered)
#   F1:        0.883 (Balance)
#
# Summary 124:
#   Precision: 0.839 (How much info is correct)
#   Recall:    0.807 (How much reference is covered)
#   F1:        0.823 (Balance)
#
# Summary 125:
#   Precision: 0.899 (How much info is correct)
#   Recall:    0.828 (How much reference is covered)
#   F1:        0.862 (Balance)
#
# Summary 126:
#   Precision: 0.873 (How much info is correct)
#   Recall:    0.794 (How much reference is covered)
#   F1:        0.832 (Balance)
#
# Summary 127:
#   Precision: 0.846 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.832 (Balance)
#
# Summary 128:
#   Precision: 0.875 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 129:
#   Precision: 0.874 (How much info is correct)
#   Recall:    0.844 (How much reference is covered)
#   F1:        0.859 (Balance)
#
# Summary 130:
#   Precision: 0.951 (How much info is correct)
#   Recall:    0.839 (How much reference is covered)
#   F1:        0.891 (Balance)
#
# Summary 131:
#   Precision: 0.890 (How much info is correct)
#   Recall:    0.859 (How much reference is covered)
#   F1:        0.875 (Balance)
#
# Summary 132:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 133:
#   Precision: 0.956 (How much info is correct)
#   Recall:    0.856 (How much reference is covered)
#   F1:        0.903 (Balance)
#
# Summary 134:
#   Precision: 0.896 (How much info is correct)
#   Recall:    0.832 (How much reference is covered)
#   F1:        0.863 (Balance)
#
# Summary 135:
#   Precision: 0.839 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.822 (Balance)
#
# Summary 136:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.810 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 137:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 138:
#   Precision: 0.847 (How much info is correct)
#   Recall:    0.829 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 139:
#   Precision: 0.842 (How much info is correct)
#   Recall:    0.802 (How much reference is covered)
#   F1:        0.821 (Balance)
#
# Summary 140:
#   Precision: 0.829 (How much info is correct)
#   Recall:    0.829 (How much reference is covered)
#   F1:        0.829 (Balance)
#
# Summary 141:
#   Precision: 0.887 (How much info is correct)
#   Recall:    0.857 (How much reference is covered)
#   F1:        0.872 (Balance)
#
# Summary 142:
#   Precision: 0.865 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 143:
#   Precision: 0.832 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.818 (Balance)
#
# Summary 144:
#   Precision: 0.949 (How much info is correct)
#   Recall:    0.862 (How much reference is covered)
#   F1:        0.903 (Balance)
#
# Summary 145:
#   Precision: 0.974 (How much info is correct)
#   Recall:    0.883 (How much reference is covered)
#   F1:        0.926 (Balance)
#
# Summary 146:
#   Precision: 0.878 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.862 (Balance)
#
# Summary 147:
#   Precision: 0.841 (How much info is correct)
#   Recall:    0.800 (How much reference is covered)
#   F1:        0.820 (Balance)
#
# Summary 148:
#   Precision: 0.940 (How much info is correct)
#   Recall:    0.855 (How much reference is covered)
#   F1:        0.896 (Balance)
#
# Summary 149:
#   Precision: 0.964 (How much info is correct)
#   Recall:    0.913 (How much reference is covered)
#   F1:        0.938 (Balance)
#
# Summary 150:
#   Precision: 0.957 (How much info is correct)
#   Recall:    0.855 (How much reference is covered)
#   F1:        0.903 (Balance)
#
# Summary 151:
#   Precision: 0.951 (How much info is correct)
#   Recall:    0.871 (How much reference is covered)
#   F1:        0.910 (Balance)
#
# Summary 152:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.838 (How much reference is covered)
#   F1:        0.850 (Balance)
#
# Summary 153:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 154:
#   Precision: 0.846 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 155:
#   Precision: 0.894 (How much info is correct)
#   Recall:    0.848 (How much reference is covered)
#   F1:        0.871 (Balance)
#
# Summary 156:
#   Precision: 0.946 (How much info is correct)
#   Recall:    0.868 (How much reference is covered)
#   F1:        0.905 (Balance)
#
# Summary 157:
#   Precision: 0.854 (How much info is correct)
#   Recall:    0.775 (How much reference is covered)
#   F1:        0.813 (Balance)
#
# Summary 158:
#   Precision: 0.743 (How much info is correct)
#   Recall:    0.779 (How much reference is covered)
#   F1:        0.760 (Balance)
#
# Summary 159:
#   Precision: 0.903 (How much info is correct)
#   Recall:    0.867 (How much reference is covered)
#   F1:        0.884 (Balance)
#
# Summary 160:
#   Precision: 0.835 (How much info is correct)
#   Recall:    0.824 (How much reference is covered)
#   F1:        0.829 (Balance)
#
# Summary 161:
#   Precision: 0.946 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.893 (Balance)
#
# Summary 162:
#   Precision: 0.820 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.813 (Balance)
#
# Summary 163:
#   Precision: 0.929 (How much info is correct)
#   Recall:    0.924 (How much reference is covered)
#   F1:        0.926 (Balance)
#
# Summary 164:
#   Precision: 0.772 (How much info is correct)
#   Recall:    0.791 (How much reference is covered)
#   F1:        0.781 (Balance)
#
# Summary 165:
#   Precision: 0.936 (How much info is correct)
#   Recall:    0.838 (How much reference is covered)
#   F1:        0.884 (Balance)
#
# Summary 166:
#   Precision: 0.892 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 167:
#   Precision: 0.892 (How much info is correct)
#   Recall:    0.860 (How much reference is covered)
#   F1:        0.876 (Balance)
#
# Summary 168:
#   Precision: 0.882 (How much info is correct)
#   Recall:    0.822 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 169:
#   Precision: 0.947 (How much info is correct)
#   Recall:    0.838 (How much reference is covered)
#   F1:        0.889 (Balance)
#
# Summary 170:
#   Precision: 0.829 (How much info is correct)
#   Recall:    0.824 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 171:
#   Precision: 0.890 (How much info is correct)
#   Recall:    0.840 (How much reference is covered)
#   F1:        0.864 (Balance)
#
# Summary 172:
#   Precision: 0.845 (How much info is correct)
#   Recall:    0.811 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 173:
#   Precision: 0.847 (How much info is correct)
#   Recall:    0.855 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 174:
#   Precision: 0.895 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.872 (Balance)
#
# Summary 175:
#   Precision: 0.865 (How much info is correct)
#   Recall:    0.810 (How much reference is covered)
#   F1:        0.836 (Balance)
#
# Summary 176:
#   Precision: 0.930 (How much info is correct)
#   Recall:    0.836 (How much reference is covered)
#   F1:        0.881 (Balance)
#
# Summary 177:
#   Precision: 0.890 (How much info is correct)
#   Recall:    0.864 (How much reference is covered)
#   F1:        0.877 (Balance)
#
# Summary 178:
#   Precision: 0.883 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 179:
#   Precision: 0.963 (How much info is correct)
#   Recall:    0.856 (How much reference is covered)
#   F1:        0.906 (Balance)
#
# Summary 180:
#   Precision: 0.834 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 181:
#   Precision: 0.875 (How much info is correct)
#   Recall:    0.847 (How much reference is covered)
#   F1:        0.861 (Balance)
#
# Summary 182:
#   Precision: 0.825 (How much info is correct)
#   Recall:    0.782 (How much reference is covered)
#   F1:        0.803 (Balance)
#
# Summary 183:
#   Precision: 0.894 (How much info is correct)
#   Recall:    0.852 (How much reference is covered)
#   F1:        0.872 (Balance)
#
# Summary 184:
#   Precision: 0.838 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 185:
#   Precision: 0.775 (How much info is correct)
#   Recall:    0.806 (How much reference is covered)
#   F1:        0.790 (Balance)
#
# Summary 186:
#   Precision: 0.900 (How much info is correct)
#   Recall:    0.840 (How much reference is covered)
#   F1:        0.869 (Balance)
#
# Summary 187:
#   Precision: 0.848 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.833 (Balance)
#
# Summary 188:
#   Precision: 0.975 (How much info is correct)
#   Recall:    0.874 (How much reference is covered)
#   F1:        0.921 (Balance)
#
# Summary 189:
#   Precision: 0.861 (How much info is correct)
#   Recall:    0.810 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 190:
#   Precision: 0.865 (How much info is correct)
#   Recall:    0.825 (How much reference is covered)
#   F1:        0.845 (Balance)
#
# Summary 191:
#   Precision: 0.894 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.871 (Balance)
#
# Summary 192:
#   Precision: 0.739 (How much info is correct)
#   Recall:    0.794 (How much reference is covered)
#   F1:        0.766 (Balance)
#
# Summary 193:
#   Precision: 0.841 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 194:
#   Precision: 0.944 (How much info is correct)
#   Recall:    0.895 (How much reference is covered)
#   F1:        0.919 (Balance)
#
# Summary 195:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 196:
#   Precision: 0.828 (How much info is correct)
#   Recall:    0.783 (How much reference is covered)
#   F1:        0.805 (Balance)
#
# Summary 197:
#   Precision: 0.877 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.848 (Balance)
#
# Summary 198:
#   Precision: 0.843 (How much info is correct)
#   Recall:    0.810 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 199:
#   Precision: 0.842 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.831 (Balance)
#
# Summary 200:
#   Precision: 0.946 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.880 (Balance)
#
# Summary 201:
#   Precision: 0.797 (How much info is correct)
#   Recall:    0.760 (How much reference is covered)
#   F1:        0.778 (Balance)
#
# Summary 202:
#   Precision: 0.874 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.848 (Balance)
#
# Summary 203:
#   Precision: 0.837 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.830 (Balance)
#
# Summary 204:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.806 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 205:
#   Precision: 0.871 (How much info is correct)
#   Recall:    0.849 (How much reference is covered)
#   F1:        0.860 (Balance)
#
# Summary 206:
#   Precision: 0.871 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 207:
#   Precision: 0.893 (How much info is correct)
#   Recall:    0.867 (How much reference is covered)
#   F1:        0.879 (Balance)
#
# Summary 208:
#   Precision: 0.971 (How much info is correct)
#   Recall:    0.885 (How much reference is covered)
#   F1:        0.926 (Balance)
#
# Summary 209:
#   Precision: 0.977 (How much info is correct)
#   Recall:    0.857 (How much reference is covered)
#   F1:        0.913 (Balance)
#
# Summary 210:
#   Precision: 0.850 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 211:
#   Precision: 0.867 (How much info is correct)
#   Recall:    0.847 (How much reference is covered)
#   F1:        0.857 (Balance)
#
# Summary 212:
#   Precision: 0.920 (How much info is correct)
#   Recall:    0.867 (How much reference is covered)
#   F1:        0.893 (Balance)
#
# Summary 213:
#   Precision: 0.869 (How much info is correct)
#   Recall:    0.797 (How much reference is covered)
#   F1:        0.831 (Balance)
#
# Summary 214:
#   Precision: 0.850 (How much info is correct)
#   Recall:    0.832 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 215:
#   Precision: 0.905 (How much info is correct)
#   Recall:    0.865 (How much reference is covered)
#   F1:        0.885 (Balance)
#
# Summary 216:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.836 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 217:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.787 (How much reference is covered)
#   F1:        0.820 (Balance)
#
# Summary 218:
#   Precision: 0.965 (How much info is correct)
#   Recall:    0.880 (How much reference is covered)
#   F1:        0.920 (Balance)
#
# Summary 219:
#   Precision: 0.962 (How much info is correct)
#   Recall:    0.842 (How much reference is covered)
#   F1:        0.898 (Balance)
#
# Summary 220:
#   Precision: 0.977 (How much info is correct)
#   Recall:    0.849 (How much reference is covered)
#   F1:        0.909 (Balance)
#
# Summary 221:
#   Precision: 0.850 (How much info is correct)
#   Recall:    0.795 (How much reference is covered)
#   F1:        0.822 (Balance)
#
# Summary 222:
#   Precision: 0.964 (How much info is correct)
#   Recall:    0.858 (How much reference is covered)
#   F1:        0.908 (Balance)
#
# Summary 223:
#   Precision: 0.872 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.845 (Balance)
#
# Summary 224:
#   Precision: 0.834 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.827 (Balance)
#
# Summary 225:
#   Precision: 0.852 (How much info is correct)
#   Recall:    0.822 (How much reference is covered)
#   F1:        0.837 (Balance)
#
# Summary 226:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.812 (How much reference is covered)
#   F1:        0.833 (Balance)
#
# Summary 227:
#   Precision: 0.962 (How much info is correct)
#   Recall:    0.871 (How much reference is covered)
#   F1:        0.914 (Balance)
#
# Summary 228:
#   Precision: 0.841 (How much info is correct)
#   Recall:    0.747 (How much reference is covered)
#   F1:        0.791 (Balance)
#
# Summary 229:
#   Precision: 0.937 (How much info is correct)
#   Recall:    0.864 (How much reference is covered)
#   F1:        0.899 (Balance)
#
# Summary 230:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.828 (How much reference is covered)
#   F1:        0.839 (Balance)
#
# Summary 231:
#   Precision: 0.778 (How much info is correct)
#   Recall:    0.737 (How much reference is covered)
#   F1:        0.757 (Balance)
#
# Summary 232:
#   Precision: 0.860 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.840 (Balance)
#
# Summary 233:
#   Precision: 0.840 (How much info is correct)
#   Recall:    0.844 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 234:
#   Precision: 0.954 (How much info is correct)
#   Recall:    0.880 (How much reference is covered)
#   F1:        0.916 (Balance)
#
# Summary 235:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.849 (Balance)
#
# Summary 236:
#   Precision: 0.875 (How much info is correct)
#   Recall:    0.865 (How much reference is covered)
#   F1:        0.870 (Balance)
#
# Summary 237:
#   Precision: 0.852 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 238:
#   Precision: 0.949 (How much info is correct)
#   Recall:    0.890 (How much reference is covered)
#   F1:        0.919 (Balance)
#
# Summary 239:
#   Precision: 0.844 (How much info is correct)
#   Recall:    0.862 (How much reference is covered)
#   F1:        0.853 (Balance)
#
# Summary 240:
#   Precision: 0.853 (How much info is correct)
#   Recall:    0.827 (How much reference is covered)
#   F1:        0.840 (Balance)
#
# Summary 241:
#   Precision: 0.848 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 242:
#   Precision: 0.822 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.818 (Balance)
#
# Summary 243:
#   Precision: 0.847 (How much info is correct)
#   Recall:    0.781 (How much reference is covered)
#   F1:        0.813 (Balance)
#
# Summary 244:
#   Precision: 0.888 (How much info is correct)
#   Recall:    0.862 (How much reference is covered)
#   F1:        0.875 (Balance)
#
# Summary 245:
#   Precision: 0.830 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 246:
#   Precision: 0.933 (How much info is correct)
#   Recall:    0.883 (How much reference is covered)
#   F1:        0.908 (Balance)
#
# Summary 247:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.844 (Balance)
#
# Summary 248:
#   Precision: 0.865 (How much info is correct)
#   Recall:    0.830 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 249:
#   Precision: 0.846 (How much info is correct)
#   Recall:    0.830 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 250:
#   Precision: 0.871 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 251:
#   Precision: 0.976 (How much info is correct)
#   Recall:    0.908 (How much reference is covered)
#   F1:        0.941 (Balance)
#
# Summary 252:
#   Precision: 0.860 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.845 (Balance)
#
# Summary 253:
#   Precision: 0.823 (How much info is correct)
#   Recall:    0.830 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 254:
#   Precision: 0.866 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.848 (Balance)
#
# Summary 255:
#   Precision: 0.935 (How much info is correct)
#   Recall:    0.852 (How much reference is covered)
#   F1:        0.892 (Balance)
#
# Summary 256:
#   Precision: 0.842 (How much info is correct)
#   Recall:    0.800 (How much reference is covered)
#   F1:        0.821 (Balance)
#
# Summary 257:
#   Precision: 0.884 (How much info is correct)
#   Recall:    0.836 (How much reference is covered)
#   F1:        0.859 (Balance)
#
# Summary 258:
#   Precision: 0.844 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.830 (Balance)
#
# Summary 259:
#   Precision: 0.831 (How much info is correct)
#   Recall:    0.802 (How much reference is covered)
#   F1:        0.816 (Balance)
#
# Summary 260:
#   Precision: 0.875 (How much info is correct)
#   Recall:    0.861 (How much reference is covered)
#   F1:        0.868 (Balance)
#
# Summary 261:
#   Precision: 0.940 (How much info is correct)
#   Recall:    0.904 (How much reference is covered)
#   F1:        0.922 (Balance)
#
# Summary 262:
#   Precision: 0.923 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.883 (Balance)
#
# Summary 263:
#   Precision: 0.832 (How much info is correct)
#   Recall:    0.839 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 264:
#   Precision: 0.884 (How much info is correct)
#   Recall:    0.834 (How much reference is covered)
#   F1:        0.858 (Balance)
#
# Summary 265:
#   Precision: 0.985 (How much info is correct)
#   Recall:    0.881 (How much reference is covered)
#   F1:        0.930 (Balance)
#
# Summary 266:
#   Precision: 0.915 (How much info is correct)
#   Recall:    0.803 (How much reference is covered)
#   F1:        0.855 (Balance)
#
# Summary 267:
#   Precision: 0.826 (How much info is correct)
#   Recall:    0.804 (How much reference is covered)
#   F1:        0.815 (Balance)
#
# Summary 268:
#   Precision: 0.826 (How much info is correct)
#   Recall:    0.824 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 269:
#   Precision: 0.810 (How much info is correct)
#   Recall:    0.780 (How much reference is covered)
#   F1:        0.795 (Balance)
#
# Summary 270:
#   Precision: 0.885 (How much info is correct)
#   Recall:    0.840 (How much reference is covered)
#   F1:        0.862 (Balance)
#
# Summary 271:
#   Precision: 0.868 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.849 (Balance)
#
# Summary 272:
#   Precision: 0.936 (How much info is correct)
#   Recall:    0.853 (How much reference is covered)
#   F1:        0.892 (Balance)
#
# Summary 273:
#   Precision: 0.934 (How much info is correct)
#   Recall:    0.903 (How much reference is covered)
#   F1:        0.918 (Balance)
#
# Summary 274:
#   Precision: 0.837 (How much info is correct)
#   Recall:    0.844 (How much reference is covered)
#   F1:        0.841 (Balance)
#
# Summary 275:
#   Precision: 0.862 (How much info is correct)
#   Recall:    0.833 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 276:
#   Precision: 0.852 (How much info is correct)
#   Recall:    0.833 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 277:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 278:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.830 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 279:
#   Precision: 0.916 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.869 (Balance)
#
# Summary 280:
#   Precision: 0.775 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.790 (Balance)
#
# Summary 281:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 282:
#   Precision: 0.972 (How much info is correct)
#   Recall:    0.882 (How much reference is covered)
#   F1:        0.925 (Balance)
#
# Summary 283:
#   Precision: 0.905 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.857 (Balance)
#
# Summary 284:
#   Precision: 0.902 (How much info is correct)
#   Recall:    0.864 (How much reference is covered)
#   F1:        0.882 (Balance)
#
# Summary 285:
#   Precision: 0.818 (How much info is correct)
#   Recall:    0.822 (How much reference is covered)
#   F1:        0.820 (Balance)
#
# Summary 286:
#   Precision: 0.778 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.803 (Balance)
#
# Summary 287:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.845 (How much reference is covered)
#   F1:        0.848 (Balance)
#
# Summary 288:
#   Precision: 0.875 (How much info is correct)
#   Recall:    0.855 (How much reference is covered)
#   F1:        0.865 (Balance)
#
# Summary 289:
#   Precision: 0.856 (How much info is correct)
#   Recall:    0.832 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 290:
#   Precision: 0.868 (How much info is correct)
#   Recall:    0.822 (How much reference is covered)
#   F1:        0.844 (Balance)
#
# Summary 291:
#   Precision: 0.839 (How much info is correct)
#   Recall:    0.812 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 292:
#   Precision: 0.849 (How much info is correct)
#   Recall:    0.803 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 293:
#   Precision: 0.771 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.791 (Balance)
#
# Summary 294:
#   Precision: 0.821 (How much info is correct)
#   Recall:    0.703 (How much reference is covered)
#   F1:        0.757 (Balance)
#
# Summary 295:
#   Precision: 0.805 (How much info is correct)
#   Recall:    0.776 (How much reference is covered)
#   F1:        0.790 (Balance)
#
# Summary 296:
#   Precision: 0.897 (How much info is correct)
#   Recall:    0.859 (How much reference is covered)
#   F1:        0.878 (Balance)
#
# Summary 297:
#   Precision: 0.808 (How much info is correct)
#   Recall:    0.803 (How much reference is covered)
#   F1:        0.805 (Balance)
#
# Summary 298:
#   Precision: 0.900 (How much info is correct)
#   Recall:    0.892 (How much reference is covered)
#   F1:        0.896 (Balance)
#
# Summary 299:
#   Precision: 0.840 (How much info is correct)
#   Recall:    0.831 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 300:
#   Precision: 0.872 (How much info is correct)
#   Recall:    0.843 (How much reference is covered)
#   F1:        0.857 (Balance)
#
# Summary 301:
#   Precision: 0.929 (How much info is correct)
#   Recall:    0.845 (How much reference is covered)
#   F1:        0.885 (Balance)
#
# Summary 302:
#   Precision: 0.816 (How much info is correct)
#   Recall:    0.828 (How much reference is covered)
#   F1:        0.822 (Balance)
#
# Summary 303:
#   Precision: 0.853 (How much info is correct)
#   Recall:    0.833 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 304:
#   Precision: 0.954 (How much info is correct)
#   Recall:    0.856 (How much reference is covered)
#   F1:        0.902 (Balance)
#
# Summary 305:
#   Precision: 0.856 (How much info is correct)
#   Recall:    0.832 (How much reference is covered)
#   F1:        0.844 (Balance)
#
# Summary 306:
#   Precision: 0.832 (How much info is correct)
#   Recall:    0.828 (How much reference is covered)
#   F1:        0.830 (Balance)
#
# Summary 307:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.845 (Balance)
#
# Summary 308:
#   Precision: 0.848 (How much info is correct)
#   Recall:    0.725 (How much reference is covered)
#   F1:        0.781 (Balance)
#
# Summary 309:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.759 (How much reference is covered)
#   F1:        0.805 (Balance)
#
# Summary 310:
#   Precision: 0.890 (How much info is correct)
#   Recall:    0.863 (How much reference is covered)
#   F1:        0.876 (Balance)
#
# Summary 311:
#   Precision: 0.843 (How much info is correct)
#   Recall:    0.795 (How much reference is covered)
#   F1:        0.818 (Balance)
#
# Summary 312:
#   Precision: 0.916 (How much info is correct)
#   Recall:    0.857 (How much reference is covered)
#   F1:        0.885 (Balance)
#
# Summary 313:
#   Precision: 0.889 (How much info is correct)
#   Recall:    0.820 (How much reference is covered)
#   F1:        0.853 (Balance)
#
# Summary 314:
#   Precision: 0.809 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.808 (Balance)
#
# Summary 315:
#   Precision: 0.875 (How much info is correct)
#   Recall:    0.829 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 316:
#   Precision: 0.892 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.852 (Balance)
#
# Summary 317:
#   Precision: 0.905 (How much info is correct)
#   Recall:    0.863 (How much reference is covered)
#   F1:        0.884 (Balance)
#
# Summary 318:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.806 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 319:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 320:
#   Precision: 0.874 (How much info is correct)
#   Recall:    0.822 (How much reference is covered)
#   F1:        0.847 (Balance)
#
# Summary 321:
#   Precision: 0.943 (How much info is correct)
#   Recall:    0.876 (How much reference is covered)
#   F1:        0.908 (Balance)
#
# Summary 322:
#   Precision: 0.969 (How much info is correct)
#   Recall:    0.894 (How much reference is covered)
#   F1:        0.930 (Balance)
#
# Summary 323:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.836 (Balance)
#
# Summary 324:
#   Precision: 0.911 (How much info is correct)
#   Recall:    0.861 (How much reference is covered)
#   F1:        0.885 (Balance)
#
# Summary 325:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.859 (How much reference is covered)
#   F1:        0.861 (Balance)
#
# Summary 326:
#   Precision: 0.819 (How much info is correct)
#   Recall:    0.824 (How much reference is covered)
#   F1:        0.821 (Balance)
#
# Summary 327:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.813 (How much reference is covered)
#   F1:        0.837 (Balance)
#
# Summary 328:
#   Precision: 0.886 (How much info is correct)
#   Recall:    0.857 (How much reference is covered)
#   F1:        0.872 (Balance)
#
# Summary 329:
#   Precision: 0.827 (How much info is correct)
#   Recall:    0.800 (How much reference is covered)
#   F1:        0.814 (Balance)
#
# Summary 330:
#   Precision: 0.798 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.808 (Balance)
#
# Summary 331:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 332:
#   Precision: 0.943 (How much info is correct)
#   Recall:    0.848 (How much reference is covered)
#   F1:        0.893 (Balance)
#
# Summary 333:
#   Precision: 0.931 (How much info is correct)
#   Recall:    0.844 (How much reference is covered)
#   F1:        0.886 (Balance)
#
# Summary 334:
#   Precision: 0.952 (How much info is correct)
#   Recall:    0.869 (How much reference is covered)
#   F1:        0.909 (Balance)
#
# Summary 335:
#   Precision: 0.883 (How much info is correct)
#   Recall:    0.844 (How much reference is covered)
#   F1:        0.863 (Balance)
#
# Summary 336:
#   Precision: 0.859 (How much info is correct)
#   Recall:    0.833 (How much reference is covered)
#   F1:        0.846 (Balance)
#
# Summary 337:
#   Precision: 0.778 (How much info is correct)
#   Recall:    0.839 (How much reference is covered)
#   F1:        0.808 (Balance)
#
# Summary 338:
#   Precision: 0.787 (How much info is correct)
#   Recall:    0.846 (How much reference is covered)
#   F1:        0.815 (Balance)
#
# Summary 339:
#   Precision: 0.830 (How much info is correct)
#   Recall:    0.705 (How much reference is covered)
#   F1:        0.762 (Balance)
#
# Summary 340:
#   Precision: 0.866 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 341:
#   Precision: 0.921 (How much info is correct)
#   Recall:    0.868 (How much reference is covered)
#   F1:        0.894 (Balance)
#
# Summary 342:
#   Precision: 0.845 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 343:
#   Precision: 0.946 (How much info is correct)
#   Recall:    0.829 (How much reference is covered)
#   F1:        0.884 (Balance)
#
# Summary 344:
#   Precision: 0.835 (How much info is correct)
#   Recall:    0.803 (How much reference is covered)
#   F1:        0.818 (Balance)
#
# Summary 345:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.823 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 346:
#   Precision: 0.831 (How much info is correct)
#   Recall:    0.832 (How much reference is covered)
#   F1:        0.832 (Balance)
#
# Summary 347:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.795 (How much reference is covered)
#   F1:        0.824 (Balance)
#
# Summary 348:
#   Precision: 0.831 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.825 (Balance)
#
# Summary 349:
#   Precision: 0.886 (How much info is correct)
#   Recall:    0.830 (How much reference is covered)
#   F1:        0.857 (Balance)
#
# Summary 350:
#   Precision: 0.887 (How much info is correct)
#   Recall:    0.857 (How much reference is covered)
#   F1:        0.871 (Balance)
#
# Summary 351:
#   Precision: 0.836 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 352:
#   Precision: 0.846 (How much info is correct)
#   Recall:    0.828 (How much reference is covered)
#   F1:        0.837 (Balance)
#
# Summary 353:
#   Precision: 0.960 (How much info is correct)
#   Recall:    0.897 (How much reference is covered)
#   F1:        0.928 (Balance)
#
# Summary 354:
#   Precision: 0.813 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.817 (Balance)
#
# Summary 355:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.837 (Balance)
#
# Summary 356:
#   Precision: 0.805 (How much info is correct)
#   Recall:    0.801 (How much reference is covered)
#   F1:        0.803 (Balance)
#
# Summary 357:
#   Precision: 0.855 (How much info is correct)
#   Recall:    0.798 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 358:
#   Precision: 0.904 (How much info is correct)
#   Recall:    0.829 (How much reference is covered)
#   F1:        0.865 (Balance)
#
# Summary 359:
#   Precision: 0.853 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.835 (Balance)
#
# Summary 360:
#   Precision: 0.839 (How much info is correct)
#   Recall:    0.800 (How much reference is covered)
#   F1:        0.819 (Balance)
#
# Summary 361:
#   Precision: 0.888 (How much info is correct)
#   Recall:    0.842 (How much reference is covered)
#   F1:        0.865 (Balance)
#
# Summary 362:
#   Precision: 0.910 (How much info is correct)
#   Recall:    0.871 (How much reference is covered)
#   F1:        0.890 (Balance)
#
# Summary 363:
#   Precision: 0.863 (How much info is correct)
#   Recall:    0.838 (How much reference is covered)
#   F1:        0.851 (Balance)
#
# Summary 364:
#   Precision: 0.861 (How much info is correct)
#   Recall:    0.862 (How much reference is covered)
#   F1:        0.861 (Balance)
#
# Summary 365:
#   Precision: 0.765 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.791 (Balance)
#
# Summary 366:
#   Precision: 0.966 (How much info is correct)
#   Recall:    0.865 (How much reference is covered)
#   F1:        0.913 (Balance)
#
# Summary 367:
#   Precision: 0.868 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.846 (Balance)
#
# Summary 368:
#   Precision: 0.864 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 369:
#   Precision: 0.928 (How much info is correct)
#   Recall:    0.902 (How much reference is covered)
#   F1:        0.915 (Balance)
#
# Summary 370:
#   Precision: 0.867 (How much info is correct)
#   Recall:    0.838 (How much reference is covered)
#   F1:        0.852 (Balance)
#
# Summary 371:
#   Precision: 0.833 (How much info is correct)
#   Recall:    0.763 (How much reference is covered)
#   F1:        0.796 (Balance)
#
# Summary 372:
#   Precision: 0.961 (How much info is correct)
#   Recall:    0.876 (How much reference is covered)
#   F1:        0.917 (Balance)
#
# Summary 373:
#   Precision: 0.870 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 374:
#   Precision: 0.844 (How much info is correct)
#   Recall:    0.812 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 375:
#   Precision: 0.912 (How much info is correct)
#   Recall:    0.847 (How much reference is covered)
#   F1:        0.878 (Balance)
#
# Summary 376:
#   Precision: 0.843 (How much info is correct)
#   Recall:    0.828 (How much reference is covered)
#   F1:        0.836 (Balance)
#
# Summary 377:
#   Precision: 0.833 (How much info is correct)
#   Recall:    0.818 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 378:
#   Precision: 0.840 (How much info is correct)
#   Recall:    0.792 (How much reference is covered)
#   F1:        0.815 (Balance)
#
# Summary 379:
#   Precision: 0.851 (How much info is correct)
#   Recall:    0.835 (How much reference is covered)
#   F1:        0.843 (Balance)
#
# Summary 380:
#   Precision: 0.882 (How much info is correct)
#   Recall:    0.847 (How much reference is covered)
#   F1:        0.864 (Balance)
#
# Summary 381:
#   Precision: 0.844 (How much info is correct)
#   Recall:    0.817 (How much reference is covered)
#   F1:        0.830 (Balance)
#
# Summary 382:
#   Precision: 0.796 (How much info is correct)
#   Recall:    0.804 (How much reference is covered)
#   F1:        0.800 (Balance)
#
# Summary 383:
#   Precision: 0.817 (How much info is correct)
#   Recall:    0.821 (How much reference is covered)
#   F1:        0.819 (Balance)
#
# Summary 384:
#   Precision: 0.867 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.840 (Balance)
#
# Summary 385:
#   Precision: 0.868 (How much info is correct)
#   Recall:    0.706 (How much reference is covered)
#   F1:        0.778 (Balance)
#
# Summary 386:
#   Precision: 0.938 (How much info is correct)
#   Recall:    0.901 (How much reference is covered)
#   F1:        0.919 (Balance)
#
# Summary 387:
#   Precision: 0.831 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.819 (Balance)
#
# Summary 388:
#   Precision: 0.850 (How much info is correct)
#   Recall:    0.805 (How much reference is covered)
#   F1:        0.827 (Balance)
#
# Summary 389:
#   Precision: 0.892 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.848 (Balance)
#
# Summary 390:
#   Precision: 0.867 (How much info is correct)
#   Recall:    0.800 (How much reference is covered)
#   F1:        0.832 (Balance)
#
# Summary 391:
#   Precision: 0.859 (How much info is correct)
#   Recall:    0.811 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 392:
#   Precision: 0.869 (How much info is correct)
#   Recall:    0.832 (How much reference is covered)
#   F1:        0.850 (Balance)
#
# Summary 393:
#   Precision: 0.842 (How much info is correct)
#   Recall:    0.842 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 394:
#   Precision: 0.826 (How much info is correct)
#   Recall:    0.850 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 395:
#   Precision: 0.956 (How much info is correct)
#   Recall:    0.909 (How much reference is covered)
#   F1:        0.932 (Balance)
#
# Summary 396:
#   Precision: 0.814 (How much info is correct)
#   Recall:    0.799 (How much reference is covered)
#   F1:        0.806 (Balance)
#
# Summary 397:
#   Precision: 0.853 (How much info is correct)
#   Recall:    0.845 (How much reference is covered)
#   F1:        0.849 (Balance)
#
# Summary 398:
#   Precision: 0.862 (How much info is correct)
#   Recall:    0.837 (How much reference is covered)
#   F1:        0.849 (Balance)
#
# Summary 399:
#   Precision: 0.858 (How much info is correct)
#   Recall:    0.811 (How much reference is covered)
#   F1:        0.834 (Balance)
#
# Summary 400:
#   Precision: 0.872 (How much info is correct)
#   Recall:    0.814 (How much reference is covered)
#   F1:        0.842 (Balance)
#
# Summary 401:
#   Precision: 0.929 (How much info is correct)
#   Recall:    0.859 (How much reference is covered)
#   F1:        0.892 (Balance)
#
# Summary 402:
#   Precision: 0.919 (How much info is correct)
#   Recall:    0.868 (How much reference is covered)
#   F1:        0.893 (Balance)
#
# Summary 403:
#   Precision: 0.901 (How much info is correct)
#   Recall:    0.849 (How much reference is covered)
#   F1:        0.874 (Balance)
#
# Summary 404:
#   Precision: 0.900 (How much info is correct)
#   Recall:    0.864 (How much reference is covered)
#   F1:        0.882 (Balance)
#
# Summary 405:
#   Precision: 0.857 (How much info is correct)
#   Recall:    0.836 (How much reference is covered)
#   F1:        0.846 (Balance)
#
# Summary 406:
#   Precision: 0.844 (How much info is correct)
#   Recall:    0.808 (How much reference is covered)
#   F1:        0.826 (Balance)
#
# Summary 407:
#   Precision: 0.830 (How much info is correct)
#   Recall:    0.826 (How much reference is covered)
#   F1:        0.828 (Balance)
#
# Summary 408:
#   Precision: 0.926 (How much info is correct)
#   Recall:    0.827 (How much reference is covered)
#   F1:        0.874 (Balance)
#
# Summary 409:
#   Precision: 0.857 (How much info is correct)
#   Recall:    0.819 (How much reference is covered)
#   F1:        0.838 (Balance)
#
# Summary 410:
#   Precision: 0.828 (How much info is correct)
#   Recall:    0.810 (How much reference is covered)
#   F1:        0.819 (Balance)
#
# Summary 411:
#   Precision: 0.888 (How much info is correct)
#   Recall:    0.874 (How much reference is covered)
#   F1:        0.881 (Balance)
#
# Summary 412:
#   Precision: 0.822 (How much info is correct)
#   Recall:    0.746 (How much reference is covered)
#   F1:        0.783 (Balance)
#
# Summary 413:
#   Precision: 0.856 (How much info is correct)
#   Recall:    0.816 (How much reference is covered)
#   F1:        0.835 (Balance)

# %%
baseline = [" ".join(text.split(".")[:3]) for text in refs]
P_base, R_base, F1_base = score(baseline, refs, lang="en")

if F1.mean() > F1_base.mean():
    print("Your model outperforms baseline!")
else:
    print("Try improving your model architecture.")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Try improving your model architecture.

# %%
from google.colab import files
import shutil

# # Создаем ZIP-архив папки
shutil.make_archive('/content/t5-2000-summarizer', 'zip', '/content/t5-2000-summarizer')
# shutil.make_archive('/content/t5-lora-summarizer', 'zip', '/content/t5-lora-summarizer')

# # Скачиваем архив
# files.download('/content/t5-lora-output.zip')
# files.download('/content/t5-lora-summarizer.zip')
# Out:
# '/content/t5-2000-summarizer.zip'
